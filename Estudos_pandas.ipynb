# %%
import pandas as pd
import numpy as np
import matplotlib as plot

# %%
df = pd.read_csv("DataSet/fifa.csv")
df.drop(columns=['Unnamed: 0'], inplace = True)
df
# Out:
#            ID                Name  Age  \
# 0      158023            L. Messi   31
# 1       20801   Cristiano Ronaldo   33
# 2      190871           Neymar Jr   26
# 3      193080              De Gea   27
# 4      192985        K. De Bruyne   27
# ...       ...                 ...  ...
# 18202  238813        J. Lundstram   19
# 18203  243165  N. Christoffersson   19
# 18204  241638           B. Worman   16
# 18205  246268      D. Walker-Rice   17
# 18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# ...                                               ...         ...
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=18207, step=1)

# %%
df.Name
# Out:
# 0                  L. Messi
# 1         Cristiano Ronaldo
# 2                 Neymar Jr
# 3                    De Gea
# 4              K. De Bruyne
#                 ...
# 18202          J. Lundstram
# 18203    N. Christoffersson
# 18204             B. Worman
# 18205        D. Walker-Rice
# 18206             G. Nugent
# Name: Name, Length: 18207, dtype: object

# %%
df[["Name", "Nationality", "Wage"]]
# Out:
#                      Name Nationality   Wage
# 0                L. Messi   Argentina  €565K
# 1       Cristiano Ronaldo    Portugal  €405K
# 2               Neymar Jr      Brazil  €290K
# 3                  De Gea       Spain  €260K
# 4            K. De Bruyne     Belgium  €355K
# ...                   ...         ...    ...
# 18202        J. Lundstram     England    €1K
# 18203  N. Christoffersson      Sweden    €1K
# 18204           B. Worman     England    €1K
# 18205      D. Walker-Rice     England    €1K
# 18206           G. Nugent     England    €1K
#
# [18207 rows x 3 columns]

# %%
df.iloc[1]
# Out:
# ID                                                        20801
# Name                                          Cristiano Ronaldo
# Age                                                          33
# Photo             https://cdn.sofifa.org/players/4/19/20801.png
# Nationality                                            Portugal
#                                       ...
# GKHandling                                                 11.0
# GKKicking                                                  15.0
# GKPositioning                                              14.0
# GKReflexes                                                 11.0
# Release Clause                                          €127.1M
# Name: 1, Length: 88, dtype: object

# %%
df.iloc[0:4]
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
#
#                   Club                                     Club Logo  ...  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# ...

# %%
df.iloc[2,1]
# Out:
# 'Neymar Jr'

# %%
df.loc[df['Nationality'] == 'Brazil']
# Out:
#            ID              Name  Age  \
# 2      190871         Neymar Jr   26
# 27     200145          Casemiro   26
# 32     189242          Coutinho   26
# 35     176676           Marcelo   30
# 39     164240      Thiago Silva   33
# ...       ...               ...  ...
# 17059  243750  Gianluca Zanette   21
# 17446  235949         Strefezza   21
# 17588  244311     Lucas Ribeiro   19
# 17611  241268   Felipe Ferreyra   20
# 18170  246447   Nicolas Firmino   17
#
#                                                 Photo Nationality  \
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 27     https://cdn.sofifa.org/players/4/19/200145.png      Brazil
# 32     https://cdn.sofifa.org/players/4/19/189242.png      Brazil
# 35     https://cdn.sofifa.org/players/4/19/176676.png      Brazil
# 39     https://cdn.sofifa.org/players/4/19/164240.png      Brazil
# ...                                               ...         ...
# ...

# %%
df.loc[df['Nationality'] == 'Spain']
# Out:
#            ID                 Name  Age  \
# 3      193080               De Gea   27
# 8      155862         Sergio Ramos   32
# 13     168542          David Silva   32
# 20     189511      Sergio Busquets   29
# 30     197781                 Isco   26
# ...       ...                  ...  ...
# 17043  220190        Cristian Arco   23
# 17070  244016               Taliby   21
# 17116  245597         Víctor Gómez   18
# 17274  243194            Hugo Díaz   21
# 17926  244559  Carlos Mendes Gomes   19
#
#                                                 Photo Nationality  \
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 8      https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 13     https://cdn.sofifa.org/players/4/19/168542.png       Spain
# 20     https://cdn.sofifa.org/players/4/19/189511.png       Spain
# 30     https://cdn.sofifa.org/players/4/19/197781.png       Spain
# ...                                               ...         ...
# ...

# %%
df.loc[df['Age'] == 35]
# Out:
#            ID        Name  Age  \
# 102    171919       Naldo   35
# 108    120533        Pepe   35
# 221    156616   F. Ribéry   35
# 224     24630  Pepe Reina   35
# 314    146530  Dani Alves   35
# ...       ...         ...  ...
# 16071  137356  S. Farelli   35
# 16785  232539      K. Ogi   35
# 16936  181702   Y. Uekusa   35
# 17341  245558    G. Maley   35
# 17657   11430  J. McCombe   35
#
#                                                 Photo Nationality  \
# 102    https://cdn.sofifa.org/players/4/19/171919.png      Brazil
# 108    https://cdn.sofifa.org/players/4/19/120533.png    Portugal
# 221    https://cdn.sofifa.org/players/4/19/156616.png      France
# 224     https://cdn.sofifa.org/players/4/19/24630.png       Spain
# 314    https://cdn.sofifa.org/players/4/19/146530.png      Brazil
# ...                                               ...         ...
# 16071  https://cdn.sofifa.org/players/4/19/137356.png       Italy
# ...

# %%
df.loc[df['Age'] >= 25]
# Out:
#            ID               Name  Age  \
# 0      158023           L. Messi   31
# 1       20801  Cristiano Ronaldo   33
# 2      190871          Neymar Jr   26
# 3      193080             De Gea   27
# 4      192985       K. De Bruyne   27
# ...       ...                ...  ...
# 18055  235910         M. Mansour   26
# 18067  241303         Zhang Gong   26
# 18074  243110          Sun Qibin   26
# 18171  237746        Y. Uchimura   33
# 18183   53748      K. Pilkington   44
#
#                                                 Photo   Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png     Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png      Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png        Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png         Spain
# 4      https://cdn.sofifa.org/players/4/19/192985.png       Belgium
# ...                                               ...           ...
# ...

# %%
df.sort_values("Age")
# Out:
#            ID           Name  Age  \
# 18206  246269      G. Nugent   16
# 17743  244752      J. Olstad   16
# 13293  246594    H. Massengo   16
# 16081  241552    J. Italiano   16
# 18166  243621       N. Ayéva   16
# ...       ...            ...  ...
# 12192  208927   H. Sulaimani   41
# 10545  140183    S. Narazaki   42
# 18183   53748  K. Pilkington   44
# 17726   51963      T. Warner   44
# 4741   140029       O. Pérez   45
#
#                                                 Photo        Nationality  \
# 18206  https://cdn.sofifa.org/players/4/19/246269.png            England
# 17743  https://cdn.sofifa.org/players/4/19/244752.png             Norway
# 13293  https://cdn.sofifa.org/players/4/19/246594.png             France
# 16081  https://cdn.sofifa.org/players/4/19/241552.png          Australia
# 18166  https://cdn.sofifa.org/players/4/19/243621.png             Sweden
# ...                                               ...                ...
# ...

# %%
df.sort_values('Name')
# Out:
#            ID            Name  Age  \
# 13632  228006        A. Abang   21
# 15665  243896   A. Abdellaoui   25
# 3055   198076    A. Abdennour   28
# 6388   138698         A. Abdi   31
# 12816  245438   A. Abdu Jaber   21
# ...       ...             ...  ...
# 15334  246284       Óscar Gil   20
# 9803   229865    Óscar Pinchi   22
# 2564   208621     Óscar Plano   27
# 10353  243558  Óscar Valentín   23
# 10002  220433   Óscar Whalley   24
#
#                                                 Photo  Nationality  \
# 13632  https://cdn.sofifa.org/players/4/19/228006.png     Cameroon
# 15665  https://cdn.sofifa.org/players/4/19/243896.png      Algeria
# 3055   https://cdn.sofifa.org/players/4/19/198076.png      Tunisia
# 6388   https://cdn.sofifa.org/players/4/19/138698.png  Switzerland
# 12816  https://cdn.sofifa.org/players/4/19/245438.png      Eritrea
# ...                                               ...          ...
# ...

# %%
df.sort_values("Age", ascending=False)
# Out:
#            ID           Name  Age  \
# 4741   140029       O. Pérez   45
# 18183   53748  K. Pilkington   44
# 17726   51963      T. Warner   44
# 10545  140183    S. Narazaki   42
# 7225   142998       C. Muñoz   41
# ...       ...            ...  ...
# 17921  246601     J. Rowland   16
# 17887  246009       M. Tilio   16
# 15363  245015      Y. Roemer   16
# 17881  242165       R. Hauge   16
# 18206  246269      G. Nugent   16
#
#                                                 Photo        Nationality  \
# 4741   https://cdn.sofifa.org/players/4/19/140029.png             Mexico
# 18183   https://cdn.sofifa.org/players/4/19/53748.png            England
# 17726   https://cdn.sofifa.org/players/4/19/51963.png  Trinidad & Tobago
# 10545  https://cdn.sofifa.org/players/4/19/140183.png              Japan
# 7225   https://cdn.sofifa.org/players/4/19/142998.png          Argentina
# ...                                               ...                ...
# ...

# %%
df.sort_values("Name", ascending=False)
# Out:
#            ID            Name  Age  \
# 10002  220433   Óscar Whalley   24
# 10353  243558  Óscar Valentín   23
# 2564   208621     Óscar Plano   27
# 9803   229865    Óscar Pinchi   22
# 15334  246284       Óscar Gil   20
# ...       ...             ...  ...
# 12816  245438   A. Abdu Jaber   21
# 6388   138698         A. Abdi   31
# 3055   198076    A. Abdennour   28
# 15665  243896   A. Abdellaoui   25
# 13632  228006        A. Abang   21
#
#                                                 Photo  Nationality  \
# 10002  https://cdn.sofifa.org/players/4/19/220433.png        Spain
# 10353  https://cdn.sofifa.org/players/4/19/243558.png        Spain
# 2564   https://cdn.sofifa.org/players/4/19/208621.png        Spain
# 9803   https://cdn.sofifa.org/players/4/19/229865.png        Spain
# 15334  https://cdn.sofifa.org/players/4/19/246284.png        Spain
# ...                                               ...          ...
# ...

# %%
df.sort_values(["Name", "Age"])
# Out:
#            ID            Name  Age  \
# 13632  228006        A. Abang   21
# 15665  243896   A. Abdellaoui   25
# 3055   198076    A. Abdennour   28
# 6388   138698         A. Abdi   31
# 12816  245438   A. Abdu Jaber   21
# ...       ...             ...  ...
# 15334  246284       Óscar Gil   20
# 9803   229865    Óscar Pinchi   22
# 2564   208621     Óscar Plano   27
# 10353  243558  Óscar Valentín   23
# 10002  220433   Óscar Whalley   24
#
#                                                 Photo  Nationality  \
# 13632  https://cdn.sofifa.org/players/4/19/228006.png     Cameroon
# 15665  https://cdn.sofifa.org/players/4/19/243896.png      Algeria
# 3055   https://cdn.sofifa.org/players/4/19/198076.png      Tunisia
# 6388   https://cdn.sofifa.org/players/4/19/138698.png  Switzerland
# 12816  https://cdn.sofifa.org/players/4/19/245438.png      Eritrea
# ...                                               ...          ...
# ...

# %%
df.sort_values('Weight')
# Out:
#            ID            Name  Age  \
# 13338  235600   B. Al Mutairi   28
# 17157  242566    K. Yamaguchi   23
# 4390   214919        D. Rojas   23
# 7126   225150       A. Araujo   21
# 15585  227726     I. Al Talhi   23
# ...       ...             ...  ...
# 13279  239679    P. Mazzocchi   22
# 13280  244543       Y. Ammour   19
# 13281  212800  Jwa Joon Hyeop   27
# 13282  231232      O. Marrufo   25
# 13283  232256     Han Pengfei   25
#
#                                                 Photo     Nationality  \
# 13338  https://cdn.sofifa.org/players/4/19/235600.png    Saudi Arabia
# 17157  https://cdn.sofifa.org/players/4/19/242566.png           Japan
# 4390   https://cdn.sofifa.org/players/4/19/214919.png           Chile
# 7126   https://cdn.sofifa.org/players/4/19/225150.png        Portugal
# 15585  https://cdn.sofifa.org/players/4/19/227726.png    Saudi Arabia
# ...                                               ...             ...
# ...

# %%
df["Total"] = df["Acceleration"] + df['Agility'] + df['Reactions']

# %%
df.sort_values(["Total","Release Clause"], ascending=False)
# Out:
#            ID            Name  Age  \
# 2      190871       Neymar Jr   26
# 5      183277       E. Hazard   27
# 0      158023        L. Messi   31
# 26     209331        M. Salah   26
# 50     175943      D. Mertens   31
# ...       ...             ...  ...
# 13279  239679    P. Mazzocchi   22
# 13280  244543       Y. Ammour   19
# 13281  212800  Jwa Joon Hyeop   27
# 13282  231232      O. Marrufo   25
# 13283  232256     Han Pengfei   25
#
#                                                 Photo     Nationality  \
# 2      https://cdn.sofifa.org/players/4/19/190871.png          Brazil
# 5      https://cdn.sofifa.org/players/4/19/183277.png         Belgium
# 0      https://cdn.sofifa.org/players/4/19/158023.png       Argentina
# 26     https://cdn.sofifa.org/players/4/19/209331.png           Egypt
# 50     https://cdn.sofifa.org/players/4/19/175943.png         Belgium
# ...                                               ...             ...
# ...

# %%
df_1 = df[["Name", "Total"]]

# %%
df_1 = df_1.sort_values('Total', ascending=False).reset_index()

# %%
df_1.drop(columns=['index'], inplace=True)

# %%
df_1.dtypes
# Out:
# Name      object
# Total    float64
# dtype: object

# %%
df_1
# Out:
#                  Name  Total
# 0           Neymar Jr  284.0
# 1           E. Hazard  279.0
# 2            L. Messi  277.0
# 3            M. Salah  276.0
# 4          D. Mertens  275.0
# ...               ...    ...
# 18202    P. Mazzocchi    NaN
# 18203       Y. Ammour    NaN
# 18204  Jwa Joon Hyeop    NaN
# 18205      O. Marrufo    NaN
# 18206     Han Pengfei    NaN
#
# [18207 rows x 2 columns]

# %%
df_1.head
# Out:
# <bound method NDFrame.head of                  Name  Total
# 0           Neymar Jr  284.0
# 1           E. Hazard  279.0
# 2            L. Messi  277.0
# 3            M. Salah  276.0
# 4          D. Mertens  275.0
# ...               ...    ...
# 18202    P. Mazzocchi    NaN
# 18203       Y. Ammour    NaN
# 18204  Jwa Joon Hyeop    NaN
# 18205      O. Marrufo    NaN
# 18206     Han Pengfei    NaN
#
# [18207 rows x 2 columns]>

# %%
df_1.to_csv("DataSet/dados1.csv", index=False)

# %%
df_1.to_excel("DataSet/dados.xlsx", index=False)

# %%
df_1.to_json("DataSet/dadosJson.json")

# %%
df_1.to_csv("DataSet/dadosTxt.txt", index=False, sep = '\t')
