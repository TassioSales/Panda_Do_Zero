# %%
import pandas as pd
import re

# %%
df = pd.read_csv("DataSet/house.csv")

# %%
df1 = df

# %%
filter1 = df.loc[df["Rooms"] == 3]
filter1
# Out:
#               Suburb            Address  Rooms Type      Price Method  \
# 0         Abbotsford      49 Lithgow St      3    h  1490000.0      S
# 1         Abbotsford      59A Turner St      3    h  1220000.0      S
# 2         Abbotsford      119B Yarra St      3    h  1420000.0      S
# 3         Aberfeldie         68 Vida St      3    h  1515000.0      S
# 7       Airport West  1/26 Highridge Cr      3    h   715000.0     SP
# ...              ...                ...    ...  ...        ...    ...
# 63017        Preston      229 Murray Rd      3    h   808000.0      S
# 63018  Roxburgh Park          3 Carr Pl      3    h   566000.0      S
# 63019  Roxburgh Park        9 Parker Ct      3    h   500000.0      S
# 63020  Roxburgh Park     5 Parkinson Wy      3    h   545000.0      S
# 63021     Thomastown     3/1 Travers St      3    u        NaN     PI
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
filter1 = df.loc[(df["Rooms"] == 3) & (df['Type'] == 'h')]
filter1
# Out:
#               Suburb            Address  Rooms Type      Price Method  \
# 0         Abbotsford      49 Lithgow St      3    h  1490000.0      S
# 1         Abbotsford      59A Turner St      3    h  1220000.0      S
# 2         Abbotsford      119B Yarra St      3    h  1420000.0      S
# 3         Aberfeldie         68 Vida St      3    h  1515000.0      S
# 7       Airport West  1/26 Highridge Cr      3    h   715000.0     SP
# ...              ...                ...    ...  ...        ...    ...
# 63011        Doveton      12 Scarlet Dr      3    h   595000.0     PI
# 63017        Preston      229 Murray Rd      3    h   808000.0      S
# 63018  Roxburgh Park          3 Carr Pl      3    h   566000.0      S
# 63019  Roxburgh Park        9 Parker Ct      3    h   500000.0      S
# 63020  Roxburgh Park     5 Parkinson Wy      3    h   545000.0      S
#
#         SellerG        Date  Postcode                  Regionname  \
# ...

# %%
filter1 = df.loc[(df["Rooms"] == 3) & (df['Type'] == 'h') & (df['Price'] <= 500000)]
filter1
# Out:
#                  Suburb          Address  Rooms Type     Price Method  \
# 92         Broadmeadows    145 Graham St      3    h  457000.0      S
# 170         Craigieburn     7A Amstel St      3    h  356500.0      S
# 177    Cranbourne North  22 Horsfield St      3    h  475000.0      S
# 183              Dallas    31 Phillip St      3    h  455500.0      S
# 192             Delahey    1/25 Yeats Dr      3    h  335000.0      S
# ...                 ...              ...    ...  ...       ...    ...
# 62977          Werribee      4 Mekong Cl      3    h  420000.0      S
# 62997      Wyndham Vale   5 Chatswood Pl      3    h  410000.0      S
# 62998      Wyndham Vale    21 Mermaid Cr      3    h  400000.0     SP
# 63000      Wyndham Vale       8 Opala Ct      3    h  416000.0      S
# 63019     Roxburgh Park      9 Parker Ct      3    h  500000.0      S
#
#              SellerG        Date  Postcode                  Regionname  \
# ...

# %%
filter2 = df.loc[df['Address'].str.contains('turner St|turner Rd', flags=re.I)]
filter2
# Out:
#              Suburb            Address  Rooms Type      Price Method  \
# 1        Abbotsford      59A Turner St      3    h  1220000.0      S
# 2859   Malvern East       24 Turner St      6    h  4700000.0      S
# 4723        Highett       48 Turner Rd      2    h   832000.0      S
# 4987     Abbotsford       85 Turner St      2    h  1480000.0      S
# 7501        Highett       28 Turner Rd      3    h        NaN     PI
# 9647     Abbotsford       53 Turner St      2    h        NaN      S
# 9648     Abbotsford       99 Turner St      2    h        NaN      S
# 14012       Berwick        4 Turner St      5    h   536000.0      S
# 14745   Westmeadows       16 Turner St      3    h        NaN     SN
# 18960  Moonee Ponds     3/16 Turner St      2    u   550000.0     VB
# 19148    Abbotsford  106/119 Turner St      1    u   481000.0     SP
# 19609       Highett     2/20 Turner Rd      2    u   730000.0     SP
# 20043   Westmeadows       14 Turner St      3    h   586000.0      S
# ...

# %%
filter3 =  df.loc[df['Address'].str.contains('^59', flags=re.I) & (df['Price'] <= 500000)]
filter3
# Out:
#                  Suburb          Address  Rooms Type     Price Method  \
# 2220             Wallan    59 William St      3    h  424000.0      S
# 9096            Sunbury  59 Davenport Dr      3    h  499500.0      S
# 13089     Sunshine West   59 Felstead Av      3    h  465000.0      S
# 13840           Sunbury  59 Davenport Dr      3    h  499500.0      S
# 19616  Hoppers Crossing     59 Aitken Av      3    h  421600.0     SP
# 19623  Hoppers Crossing   59 Mossfiel Dr      3    h  453000.0      S
# 30441        Thomastown    59 Darebin Dr      3    h  478500.0      S
# 31889           Sunbury  59 Davenport Dr      3    h  499500.0      S
# 46682           Sunbury  59 Davenport Dr      3    h  499500.0      S
# 62903           Sunbury  59 Davenport Dr      3    h  499500.0      S
#
#              SellerG        Date  Postcode             Regionname  \
# 2220         Ruralco   2/06/2018      3756      Northern Victoria
# ...

# %%
filter4 =  df.loc[df['Address'].str.contains('^59', flags=re.I) | (df['Price'] <= 500000)]
filter4
# Out:
#               Suburb                 Address  Rooms Type      Price Method  \
# 1         Abbotsford           59A Turner St      3    h  1220000.0      S
# 21          Armadale      6/38 Wattletree Rd      1    u   355000.0      S
# 75          Box Hill         12/20 Ashted Rd      2    u   420000.0     SP
# 77         Braybrook          30 Cremorne St      2    h   490000.0      S
# 78         Braybrook          2/1 Hancock Cr      2    t   500000.0     SP
# ...              ...                     ...    ...  ...        ...    ...
# 63012      Frankston  5/33 Dandenong East Rd      2    u   375000.0     SP
# 63014      Frankston          1/34 Petrie St      2    u   345000.0     SP
# 63015      Frankston          3/34 Petrie St      2    u   340000.0     SP
# 63016      Frankston          4/34 Petrie St      2    u   347700.0     SP
# 63019  Roxburgh Park             9 Parker Ct      3    h   500000.0      S
#
# ...

# %%
df
# Out:
#                  Suburb           Address  Rooms Type      Price Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1            Abbotsford     59A Turner St      3    h  1220000.0      S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3            Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                 ...               ...    ...  ...        ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 63021        Thomastown    3/1 Travers St      3    u        NaN     PI
# 63022  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
df.loc[df['SellerG'] == 'Nelson', 'SellerG'] = 'Ronald'
df
# Out:
#                  Suburb           Address  Rooms Type      Price Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1            Abbotsford     59A Turner St      3    h  1220000.0      S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3            Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                 ...               ...    ...  ...        ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 63021        Thomastown    3/1 Travers St      3    u        NaN     PI
# 63022  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
df.loc[df['SellerG'] == 'Ronald', 'Method'] = 'Pending'
df
# Out:
#                  Suburb           Address  Rooms Type      Price   Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1490000.0        S
# 1            Abbotsford     59A Turner St      3    h  1220000.0        S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0  Pending
# 3            Aberfeldie        68 Vida St      3    h  1515000.0        S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0  Pending
# ...                 ...               ...    ...  ...        ...      ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0        S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0        S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0        S
# 63021        Thomastown    3/1 Travers St      3    u        NaN       PI
# 63022  Williams Landing       1 Diadem Wy      4    h        NaN       SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
df.loc[df['SellerG'] == 'Ronald', ['Method', 'Type']] = 'Pending'
df
# Out:
#                  Suburb           Address  Rooms     Type      Price   Method  \
# 0            Abbotsford     49 Lithgow St      3        h  1490000.0        S
# 1            Abbotsford     59A Turner St      3        h  1220000.0        S
# 2            Abbotsford     119B Yarra St      3  Pending  1420000.0  Pending
# 3            Aberfeldie        68 Vida St      3        h  1515000.0        S
# 4          Airport West  92 Clydesdale Rd      2  Pending   670000.0  Pending
# ...                 ...               ...    ...      ...        ...      ...
# 63018     Roxburgh Park         3 Carr Pl      3        h   566000.0        S
# 63019     Roxburgh Park       9 Parker Ct      3        h   500000.0        S
# 63020     Roxburgh Park    5 Parkinson Wy      3        h   545000.0        S
# 63021        Thomastown    3/1 Travers St      3        u        NaN       PI
# 63022  Williams Landing       1 Diadem Wy      4        h        NaN       SP
#
# ...

# %%
df1.groupby(["SellerG"]).sum().round().sort_values('Price', ascending=False)
# Out:
#                Rooms         Price  Postcode  Propertycount  Distance
# SellerG
# Jellis         16948  5.301902e+09  17116422       42958979   47832.0
# Ronald         13808  4.089097e+09  14489179       35455466   34410.0
# Barry          22919  4.022899e+09  21405391       54662639  108662.0
# Marshall        9437  3.337732e+09   8949613       22270034   20141.0
# hockingstuart  12635  3.174822e+09  13571171       36291698   53918.0
# ...              ...           ...       ...            ...       ...
# Harcourts/YPA      3  0.000000e+00      3075           8279      16.0
# Sahara             8  0.000000e+00      6058          23990      37.0
# Royston            3  0.000000e+00      6362          15434       9.0
# Hill               7  0.000000e+00      6359           5155      46.0
# Living             4  0.000000e+00      3030          15542      15.0
#
# [476 rows x 5 columns]

# %%
df1.groupby(["SellerG"]).mean().round().sort_values('Price', ascending=False)
# Out:
#                             Rooms      Price  Postcode  Propertycount  \
# SellerG
# For                           4.0  3780000.0    3186.0        10579.0
# Sotheby's                     3.0  2706346.0    3124.0         8721.0
# Weast                         4.0  2360000.0    3156.0         7929.0
# Buxton/Marshall               4.0  2218333.0    3145.0         4827.0
# North                         3.0  2200000.0    3103.0         5682.0
# ...                           ...        ...       ...            ...
# We                            3.0        NaN    3174.0        11806.0
# WeSell                        4.0        NaN    3171.0         7412.0
# hockingstuart/Cayzer          1.0        NaN    3181.0         7717.0
# hockingstuart/HAR             4.0        NaN    3188.0         5454.0
# hockingstuart/Purplebricks    3.0        NaN    3076.0        10926.0
#
#                             Distance
# SellerG
# For                             10.0
# ...

# %%
df1.groupby(["SellerG"]).sum().round().sort_values('Rooms', ascending=False)
# Out:
#                       Rooms         Price  Postcode  Propertycount  Distance
# SellerG
# Barry                 22919  4.022899e+09  21405391       54662639  108662.0
# Jellis                16948  5.301902e+09  17116422       42958979   47832.0
# Ray                   14961  2.953669e+09  14329293       41191735   76239.0
# Ronald                13808  4.089097e+09  14489179       35455466   34410.0
# hockingstuart         12635  3.174822e+09  13571171       36291698   53918.0
# ...                     ...           ...       ...            ...       ...
# Harcourts/Barry           2  0.000000e+00      3046           2651      11.0
# Finders                   2  1.320000e+06      3000          17496       0.0
# Batty                     2  4.450000e+05      3019           3589       9.0
# Jamie                     1  3.250000e+05      3071           8870       7.0
# hockingstuart/Cayzer      1  0.000000e+00      3181           7717       5.0
#
# [476 rows x 5 columns]

# %%
df1.groupby(["SellerG"]).sum().round().sort_values('Price', ascending=False)
# Out:
#                Rooms         Price  Postcode  Propertycount  Distance
# SellerG
# Jellis         16948  5.301902e+09  17116422       42958979   47832.0
# Ronald         13808  4.089097e+09  14489179       35455466   34410.0
# Barry          22919  4.022899e+09  21405391       54662639  108662.0
# Marshall        9437  3.337732e+09   8949613       22270034   20141.0
# hockingstuart  12635  3.174822e+09  13571171       36291698   53918.0
# ...              ...           ...       ...            ...       ...
# Harcourts/YPA      3  0.000000e+00      3075           8279      16.0
# Sahara             8  0.000000e+00      6058          23990      37.0
# Royston            3  0.000000e+00      6362          15434       9.0
# Hill               7  0.000000e+00      6359           5155      46.0
# Living             4  0.000000e+00      3030          15542      15.0
#
# [476 rows x 5 columns]
